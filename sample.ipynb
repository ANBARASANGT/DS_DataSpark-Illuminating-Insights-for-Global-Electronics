# %%
import pandas as pd
dfcur=pd.read_csv("C:/Users/anbar/OneDrive/Desktop/Global electronics/df_currency.csv")
dfcur.head()
# Out:
#          Date Currency  Exchange
# 0  2015-01-01      USD    1.0000
# 1  2015-01-01      CAD    1.1583
# 2  2015-01-01      AUD    1.2214
# 3  2015-01-01      EUR    0.8237
# 4  2015-01-01      GBP    0.6415

# %%
dfcur['Date']= pd.to_datetime(dfcur['Date'], format="%Y-%m-%d")

# %%
import pandas as pd
dfcus=pd.read_csv("C:/Users/anbar/OneDrive/Desktop/Global electronics/df_customer.csv")
dfcus.head()
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country  Continent    Birthday
# 0    South Australia     5523  Australia  Australia  1939-07-03
# 1  Western Australia     6522  Australia  Australia  1979-09-27
# 2           Victoria     3380  Australia  Australia  1947-05-26
# 3    South Australia     5223  Australia  Australia  1957-09-17
# 4           Victoria     3698  Australia  Australia  1965-11-19

# %%
import pandas as pd
dfpro=pd.read_csv("C:/Users/anbar/OneDrive/Desktop/Global electronics/df_product.csv")
dfpro.head()
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3           4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4           5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#    Unit Cost USD  Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0           6.62           12.99             101     MP4&MP3            1
# 1           6.62           12.99             101     MP4&MP3            1
# 2           7.40           14.52             101     MP4&MP3            1
# 3          11.00           21.57             101     MP4&MP3            1
# 4          11.00           21.57             101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio

# %%
import pandas as pd
dfsal=pd.read_csv("C:/Users/anbar/OneDrive/Desktop/Global electronics/df_sales.csv")
dfsal.head()
# Out:
#    Order Number  Line Item  Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1  2016-01-01           NaN       265598        10
# 1        366001          1  2016-01-01    2016-01-13      1269051         0
# 2        366001          2  2016-01-01    2016-01-13      1269051         0
# 3        366002          1  2016-01-01    2016-01-12       266019         0
# 4        366002          2  2016-01-01    2016-01-12       266019         0
#
#    ProductKey  Quantity Currency Code
# 0        1304         1           CAD
# 1        1048         2           USD
# 2        2007         1           USD
# 3        1106         7           CAD
# 4         373         1           CAD

# %%
import pandas as pd
dfsto=pd.read_csv("C:/Users/anbar/OneDrive/Desktop/Global electronics/df_stores.csv")
dfsto.head()
# Out:
#    StoreKey    Country                         State  Square Meters  \
# 0         1  Australia  Australian Capital Territory          595.0
# 1         2  Australia            Northern Territory          665.0
# 2         3  Australia               South Australia         2000.0
# 3         4  Australia                      Tasmania         2000.0
# 4         5  Australia                      Victoria         2000.0
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# 4  2015-12-09

# %%
df_sales_customers = pd.merge(dfsal, dfcus, on='CustomerKey', how='inner')

# %%
df_sales_customers

# %%
df_sales_customers_product=pd.merge(df_sales_customers,dfpro, on='ProductKey', how='inner')

# %%
df_sales_customers_product
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0            366000          1  2016-01-01           NaN       265598
# 1            366001          1  2016-01-01    2016-01-13      1269051
# 2            366001          2  2016-01-01    2016-01-13      1269051
# 3            366002          1  2016-01-01    2016-01-12       266019
# 4            366002          2  2016-01-01    2016-01-12       266019
# ...             ...        ...         ...           ...          ...
# 62879       2243030          1  2021-02-20           NaN      1216913
# 62880       2243031          1  2021-02-20    2021-02-24       511229
# 62881       2243032          1  2021-02-20    2021-02-23       331277
# 62882       2243032          2  2021-02-20    2021-02-23       331277
# 62883       2243032          3  2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code  Gender  ...    Birthday  \
# ...

# %%
df_sales_customers_product_store=pd.merge(df_sales_customers_product,dfsto, on='StoreKey', how='inner')

# %%
df_sales_customers_product_store
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0            366000          1  2016-01-01           NaN       265598
# 1            366001          1  2016-01-01    2016-01-13      1269051
# 2            366001          2  2016-01-01    2016-01-13      1269051
# 3            366002          1  2016-01-01    2016-01-12       266019
# 4            366002          2  2016-01-01    2016-01-12       266019
# ...             ...        ...         ...           ...          ...
# 62879       2243030          1  2021-02-20           NaN      1216913
# 62880       2243031          1  2021-02-20    2021-02-24       511229
# 62881       2243032          1  2021-02-20    2021-02-23       331277
# 62882       2243032          2  2021-02-20    2021-02-23       331277
# 62883       2243032          3  2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code  Gender  ...  \
# ...

# %%
pd.set_option('display.max_columns', None)   #printing full columns
#pd.set_option('display.max_rows', None)       #printing full rows
df_sales_customers_product_store
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01           NaT       265598
# 1            366001          1 2016-01-01    2016-01-13      1269051
# 2            366001          2 2016-01-01    2016-01-13      1269051
# 3            366002          1 2016-01-01    2016-01-12       266019
# 4            366002          2 2016-01-01    2016-01-12       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1 2021-02-20           NaT      1216913
# 62880       2243031          1 2021-02-20    2021-02-24       511229
# 62881       2243032          1 2021-02-20    2021-02-23       331277
# 62882       2243032          2 2021-02-20    2021-02-23       331277
# 62883       2243032          3 2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code  Gender  \
# 0            10        1304         1           CAD    Male
# ...

# %%
import pandas as pd

# %%
df_sales_customers_product_store['Order Date']= pd.to_datetime(df_sales_customers_product_store['Order Date'], format="%Y-%m-%d")

# %%
df_sales_customers_product_store['Delivery Date']= pd.to_datetime(df_sales_customers_product_store['Delivery Date'], format="%Y-%m-%d")

# %%
df_sales_customers_product_store['Open Date']= pd.to_datetime(df_sales_customers_product_store['Open Date'], format="%Y-%m-%d")

# %%
overall = pd.merge(df_sales_customers_product_store, dfcur, how='inner', left_on=['Order Date', 'Currency Code'], right_on=['Date', 'Currency'])

# %%
dfcur.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  datetime64[ns]
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 263.0+ KB

# %%
overall
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01           NaT       265598
# 1            366001          1 2016-01-01    2016-01-13      1269051
# 2            366001          2 2016-01-01    2016-01-13      1269051
# 3            366002          1 2016-01-01    2016-01-12       266019
# 4            366002          2 2016-01-01    2016-01-12       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1 2021-02-20           NaT      1216913
# 62880       2243031          1 2021-02-20    2021-02-24       511229
# 62881       2243032          1 2021-02-20    2021-02-23       331277
# 62882       2243032          2 2021-02-20    2021-02-23       331277
# 62883       2243032          3 2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code  Gender  \
# 0            10        1304         1           CAD    Male
# ...
