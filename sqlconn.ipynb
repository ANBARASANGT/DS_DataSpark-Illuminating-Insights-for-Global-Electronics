# %%
import pandas as pd
df_sales = pd.read_csv("C:/Users/anbar/OneDrive/Desktop/Global electronics/df_sales.csv")
df_sales.head()
# Out:
#    Order Number  Line Item  Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1  2016-01-01           NaN       265598        10
# 1        366001          1  2016-01-01    2016-01-13      1269051         0
# 2        366001          2  2016-01-01    2016-01-13      1269051         0
# 3        366002          1  2016-01-01    2016-01-12       266019         0
# 4        366002          2  2016-01-01    2016-01-12       266019         0
#
#    ProductKey  Quantity Currency Code
# 0        1304         1           CAD
# 1        1048         2           USD
# 2        2007         1           USD
# 3        1106         7           CAD
# 4         373         1           CAD

# %%
import pandas as pd
df_er = pd.read_csv("C:/Users/anbar/OneDrive/Desktop/Global electronics/df_currency.csv")
df_er.head()
# Out:
#          Date Currency  Exchange
# 0  2015-01-01      USD    1.0000
# 1  2015-01-01      CAD    1.1583
# 2  2015-01-01      AUD    1.2214
# 3  2015-01-01      EUR    0.8237
# 4  2015-01-01      GBP    0.6415

# %%
import pandas as pd
df_stores = pd.read_csv("C:/Users/anbar/OneDrive/Desktop/Global electronics/df_stores.csv")
df_stores.head()
# Out:
#    StoreKey    Country                         State  Square Meters  \
# 0         1  Australia  Australian Capital Territory          595.0
# 1         2  Australia            Northern Territory          665.0
# 2         3  Australia               South Australia         2000.0
# 3         4  Australia                      Tasmania         2000.0
# 4         5  Australia                      Victoria         2000.0
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# 4  2015-12-09

# %%
import pandas as pd
df_products = pd.read_csv("C:/Users/anbar/OneDrive/Desktop/Global electronics/df_product.csv")
df_products.head()
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3           4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4           5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#    Unit Cost USD  Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0           6.62           12.99             101     MP4&MP3            1
# 1           6.62           12.99             101     MP4&MP3            1
# 2           7.40           14.52             101     MP4&MP3            1
# 3          11.00           21.57             101     MP4&MP3            1
# 4          11.00           21.57             101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio

# %%
import pandas as pd
df_customer = pd.read_csv("C:/Users/anbar/OneDrive/Desktop/Global electronics/df_customer.csv")
df_customer.head()
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country  Continent    Birthday
# 0    South Australia     5523  Australia  Australia  1939-07-03
# 1  Western Australia     6522  Australia  Australia  1979-09-27
# 2           Victoria     3380  Australia  Australia  1947-05-26
# 3    South Australia     5223  Australia  Australia  1957-09-17
# 4           Victoria     3698  Australia  Australia  1965-11-19

# %%
#connecting with database
import mysql.connector
mydb = mysql.connector.connect(
 host="localhost",
 user="root",
 password="Sql@10",


)


print(mydb)
mycursor = mydb.cursor(buffered=True)

# %%
mycursor.execute("create database globalelectronics")

# %%
mycursor.execute("use globalelectronics")

# %%
mycursor.execute("create table customer (customerkey int, gender varchar(40),name varchar(40),city varchar(40),statecode varchar(10),state varchar(20),zipcode varchar(20),country varchar(20),continent varchar(20),birthday date)")

# %%
insert_query = '''
INSERT INTO customer(customerkey, gender, name, city, statecode, state, zipcode, country, continent, birthday)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
'''

# %%
mycursor.execute("ALTER TABLE customer MODIFY COLUMN state VARCHAR(50)")

# %%
mycursor.execute("ALTER TABLE customer MODIFY COLUMN statecode VARCHAR(50)")

# %%
import pandas as pd
df_customer = pd.read_csv("C:/Users/anbar/OneDrive/Desktop/Global electronics/df_customer.csv")

# %%
df_customer=df_customer.fillna(0)

# %%
data_customer = df_customer.values.tolist()

# %%
data_customer
a= [tuple(i) for i in data_customer]

# %%
mycursor.executemany(insert_query,a)
mydb.commit()

# %%
import pandas as pd
df_products = pd.read_csv("C:/Users/anbar/OneDrive/Desktop/Global electronics/df_product.csv")
df_products.head()
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3           4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4           5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#    Unit Cost USD  Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0           6.62           12.99             101     MP4&MP3            1
# 1           6.62           12.99             101     MP4&MP3            1
# 2           7.40           14.52             101     MP4&MP3            1
# 3          11.00           21.57             101     MP4&MP3            1
# 4          11.00           21.57             101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio

# %%
mycursor.execute("use globalelectronics")

# %%
mycursor.execute("create table products (productkey int,productname varchar(200),brand varchar(100),color varchar(100),unitcost decimal(10,3),unitprice decimal(10,3),subcategorykey int,subcategory varchar(100),categorykey int,category varchar(100))")

# %%
insert_query2 = '''
INSERT INTO products(productkey, productname, brand, color, unitcost, unitprice, subcategorykey, subcategory, categorykey, category)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
'''

# %%
df_products=df_products.fillna(0)

# %%
data_product = df_products.values.tolist()

# %%
data_product
b= [tuple(i) for i in data_product]

# %%
mycursor.executemany(insert_query2,b)
mydb.commit()

# %%
import pandas as pd
df_stores = pd.read_csv("C:/Users/anbar/OneDrive/Desktop/Global electronics/df_stores.csv")
df_stores.head()
# Out:
#    StoreKey    Country                         State  Square Meters  \
# 0         1  Australia  Australian Capital Territory          595.0
# 1         2  Australia            Northern Territory          665.0
# 2         3  Australia               South Australia         2000.0
# 3         4  Australia                      Tasmania         2000.0
# 4         5  Australia                      Victoria         2000.0
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# 4  2015-12-09

# %%
df_stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  67 non-null     float64
#  4   Open Date      67 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
mycursor.execute("use globalelectronics")

# %%
mycursor.execute("create table store (StoreKey int,Country varchar(200),State varchar(200),squaremeters float,opendates date)")

# %%
mycursor.execute("drop table store ")

# %%
insert_query3 = '''
INSERT INTO store(StoreKey, Country, State, squaremeters, opendates)
VALUES (%s, %s, %s, %s, %s)
'''

# %%
df_stores=df_stores.fillna(0)

# %%
data_store=df_stores.values.tolist()

# %%
data_store
c= [tuple(i) for i in data_store]

# %%
mycursor.executemany(insert_query3,c)
mydb.commit()

# %%
import pandas as pd
df_sales = pd.read_csv("C:/Users/anbar/OneDrive/Desktop/Global electronics/df_sales.csv")
df_sales.head()
# Out:
#    Order Number  Line Item  Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1  2016-01-01           NaN       265598        10
# 1        366001          1  2016-01-01    2016-01-13      1269051         0
# 2        366001          2  2016-01-01    2016-01-13      1269051         0
# 3        366002          1  2016-01-01    2016-01-12       266019         0
# 4        366002          2  2016-01-01    2016-01-12       266019         0
#
#    ProductKey  Quantity Currency Code
# 0        1304         1           CAD
# 1        1048         2           USD
# 2        2007         1           USD
# 3        1106         7           CAD
# 4         373         1           CAD

# %%
mycursor.execute("create table sales (ordernumber int,lineitem int,orderdate date,deliverydate date,customerkey int,storekey int,productkey int,quantity int,currencycode varchar(50))")

# %%
insert_query4 = '''
INSERT INTO sales(ordernumber, lineitem, orderdate, deliverydate, customerkey,storekey,productkey,quantity,currencycode)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
'''

# %%
mycursor.execute("drop table sales")

# %%
df_sales
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0            366000          1  2016-01-01             0       265598
# 1            366001          1  2016-01-01    2016-01-13      1269051
# 2            366001          2  2016-01-01    2016-01-13      1269051
# 3            366002          1  2016-01-01    2016-01-12       266019
# 4            366002          2  2016-01-01    2016-01-12       266019
# ...             ...        ...         ...           ...          ...
# 62879       2243030          1  2021-02-20             0      1216913
# 62880       2243031          1  2021-02-20    2021-02-24       511229
# 62881       2243032          1  2021-02-20    2021-02-23       331277
# 62882       2243032          2  2021-02-20    2021-02-23       331277
# 62883       2243032          3  2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
df_sales=df_sales.fillna(0)

# %%
df_sales['Delivery Date']=df_sales['Delivery Date'].replace(0, pd.NaT)

# %%
data_sales=df_sales.values.tolist()

# %%
data_sales

# %%
data_sales
d=[tuple(i) for i in data_sales]

# %%
mycursor.executemany(insert_query4,d)
mydb.commit()

# %%
import pandas as pd
df_er = pd.read_csv("C:/Users/anbar/OneDrive/Desktop/Global electronics/df_currency.csv")

# %%
df_er
# Out:
#              Date Currency  Exchange
# 0      2015-01-01      USD    1.0000
# 1      2015-01-01      CAD    1.1583
# 2      2015-01-01      AUD    1.2214
# 3      2015-01-01      EUR    0.8237
# 4      2015-01-01      GBP    0.6415
# ...           ...      ...       ...
# 11210  2021-02-20      USD    1.0000
# 11211  2021-02-20      CAD    1.2610
# 11212  2021-02-20      AUD    1.2723
# 11213  2021-02-20      EUR    0.8238
# 11214  2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
mycursor.execute("create table exchangerate(dates date,currency varchar(50),exchange decimal(10,6))")

# %%
insert_query5 = '''
INSERT INTO exchangerate(dates,currency,exchange)
VALUES (%s, %s, %s)
'''

# %%
df_er=df_er.fillna(0)

# %%
data_er=df_er.values.tolist()

# %%
data_er
e=[tuple(i) for i in data_er]

# %%
mycursor.executemany(insert_query5,e)
mydb.commit()
